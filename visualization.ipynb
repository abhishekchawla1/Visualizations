# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
plt.style.use('seaborn-pastel')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_8172\2737420197.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-pastel')

# %%
np.random.seed(123)
df=pd.DataFrame({'A':np.random.randn(365).cumsum(0),'B':np.random.randn(365).cumsum(0)+20,'C':np.random.randn(365).cumsum(0)-20})

# %%
df
# Out:
#              A          B          C
# 0    -1.085631  20.059291 -20.230904
# 1    -0.088285  21.803332 -16.659325
# 2     0.194693  20.835588 -17.055481
# 3    -1.311601  21.255156 -17.093802
# 4    -1.890202  21.462083 -19.518638
# ..         ...        ...        ...
# 360 -17.039852  36.468465 -61.792064
# 361 -16.366361  36.860543 -59.518959
# 362 -16.780118  37.607936 -59.615350
# 363 -16.104155  37.880671 -61.557482
# 364 -17.090959  38.306007 -61.894074
#
# [365 rows x 3 columns]

# %%
df.plot()
# Out:
# <Axes: >

# %%
plt.style.use('seaborn-colorblind')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_8172\1159425588.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-colorblind')

# %%
df.plot()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,10))
plt.plot(df,label='x')
plt.xlabel('Random')
plt.ylabel('Random')
plt.title('Random')
plt.legend(loc='best',bbox_to_anchor=(1,1))

# %%
df
# Out:
#              A          B          C
# 0    -1.085631  20.059291 -20.230904
# 1    -0.088285  21.803332 -16.659325
# 2     0.194693  20.835588 -17.055481
# 3    -1.311601  21.255156 -17.093802
# 4    -1.890202  21.462083 -19.518638
# ..         ...        ...        ...
# 360 -17.039852  36.468465 -61.792064
# 361 -16.366361  36.860543 -59.518959
# 362 -16.780118  37.607936 -59.615350
# 363 -16.104155  37.880671 -61.557482
# 364 -17.090959  38.306007 -61.894074
#
# [365 rows x 3 columns]

# %%
df.plot('A','B',kind='scatter',color='r')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df.plot('A','C',kind='hexbin')
# Out:
# <Axes: xlabel='A', ylabel='C'>

# %%
df.plot('A','B',kind='scatter',c='C',colormap='viridis')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df.boxplot()
plt.grid(False)

# %%
df.plot(alpha=0.7,kind='hist')
df.plot(kind='kde')
plt.legend(loc='right',bbox_to_anchor=(1.2,0.9))

# %%
df
# Out:
#              A          B          C
# 0    -1.085631  20.059291 -20.230904
# 1    -0.088285  21.803332 -16.659325
# 2     0.194693  20.835588 -17.055481
# 3    -1.311601  21.255156 -17.093802
# 4    -1.890202  21.462083 -19.518638
# ..         ...        ...        ...
# 360 -17.039852  36.468465 -61.792064
# 361 -16.366361  36.860543 -59.518959
# 362 -16.780118  37.607936 -59.615350
# 363 -16.104155  37.880671 -61.557482
# 364 -17.090959  38.306007 -61.894074
#
# [365 rows x 3 columns]

# %%
#SPLOMS

# %%
cols=['A','B','C']

# %%
fig,ax=plt.subplots(len(cols),len(cols))
for i in range(len(cols)):
    for j in range(len(cols)):
        ax[i,j].scatter(df[cols[i]],df[cols[j]],c='r',s=5)
        ax[i,j].get_xaxis().set_visible(False)
        ax[i,j].get_yaxis().set_visible(False)
        if i==len(cols)-1:
            ax[i,j].get_xaxis().set_visible(True)
        if j==0:
            ax[i,j].get_yaxis().set_visible(True)

# %%
pd.plotting.scatter_matrix(df)
# Out:
# array([[<Axes: xlabel='A', ylabel='A'>, <Axes: xlabel='B', ylabel='A'>,
#         <Axes: xlabel='C', ylabel='A'>],
#        [<Axes: xlabel='A', ylabel='B'>, <Axes: xlabel='B', ylabel='B'>,
#         <Axes: xlabel='C', ylabel='B'>],
#        [<Axes: xlabel='A', ylabel='C'>, <Axes: xlabel='B', ylabel='C'>,
#         <Axes: xlabel='C', ylabel='C'>]], dtype=object)

# %%
v1=pd.Series(np.random.normal(0,10,1000),name='v1')
v2=pd.Series(np.random.normal(60,15,1000)+2*v1,name='v2')

# %%
v1
# Out:
# 0     -17.258900
# 1       6.112378
# 2      13.093510
# 3       6.958797
# 4       3.203082
#          ...
# 995   -16.471157
# 996    -6.896402
# 997    16.780687
# 998    11.841187
# 999    -7.115727
# Name: v1, Length: 1000, dtype: float64

# %%
v1.hist(bins=np.arange(-50,50,5))
# Out:
# <Axes: >

# %%
plt.hist(v1,bins=np.arange(-50,50,5))
plt.grid(which='major')

# %%
v2.hist(bins=np.arange(-50,150,5),width=0.9)
sns.kdeplot(v2)
# Out:
# <Axes: xlabel='v2', ylabel='Density'>

# %%
v3=np.concatenate((v1,v2))

# %%
plt.hist([v1,v2],density=True)
sns.kdeplot(v3)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.histplot(v3,color='Teal',kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.pairplot(df,diag_kind='kde')

# %%
sns.jointplot(x=v1,y=v2,space=0,kind='kde')

# %%
from matplotlib.gridspec import GridSpec

# %%
g=GridSpec(3,3)

# %%
t=plt.subplot(g[0,1:])
s=plt.subplot(g[1:,0])
b=plt.subplot(g[1:,1:])
t.hist(v3)
b.scatter(v1,v2)
s.hist(v2)
# Out:
# (array([  1.,   1.,  16.,  45., 139., 265., 286., 165.,  69.,  13.]),
#  array([-46.44143744, -28.86548032, -11.2895232 ,   6.28643393,
#          23.86239105,  41.43834817,  59.01430529,  76.59026241,
#          94.16621953, 111.74217666, 129.31813378]),
#  <BarContainer object of 10 artists>)

# %%
df2=pd.DataFrame({'A':v1,'B':v2})

# %%
df2
# Out:
#              A          B
# 0   -17.258900  51.796884
# 1     6.112378  61.456393
# 2    13.093510  73.839139
# 3     6.958797  96.956357
# 4     3.203082  86.022265
# ..         ...        ...
# 995 -16.471157  14.235151
# 996  -6.896402  37.150596
# 997  16.780687  80.247830
# 998  11.841187  75.329873
# 999  -7.115727  70.574435
#
# [1000 rows x 2 columns]

# %%
pd.plotting.scatter_matrix(df2,c='g')
# Out:
# array([[<Axes: xlabel='A', ylabel='A'>, <Axes: xlabel='B', ylabel='A'>],
#        [<Axes: xlabel='A', ylabel='B'>, <Axes: xlabel='B', ylabel='B'>]],
#       dtype=object)

# %%
sns.pairplot(df2)

# %%
sns.jointplot(x=df2['A'],y=df2['B'],alpha=0.5)

# %%
sns.pairplot(df2,diag_kind='kde')

# %%
sns.swarmplot(df['A'])
# Out:
# <Axes: ylabel='A'>

# %%
sns.violinplot(df2)
# Out:
# <Axes: >
