# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\ASUS\Downloads\IMDB-Movie-Data.csv")

# %%
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.duplicated().any()
# Out:
# False

# %%
df.head(5)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df.dtypes
# Out:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %%
plt.hist(df['Votes'],bins=20,color='r')
# Out:
# (array([292., 209., 125.,  89.,  43.,  36.,  20.,   8.,   4.,   2.,   4.,
#           3.,   0.,   1.,   0.,   0.,   0.,   1.,   0.,   1.]),
#  array([1.7800000e+02, 8.9764900e+04, 1.7935180e+05, 2.6893870e+05,
#         3.5852560e+05, 4.4811250e+05, 5.3769940e+05, 6.2728630e+05,
#         7.1687320e+05, 8.0646010e+05, 8.9604700e+05, 9.8563390e+05,
#         1.0752208e+06, 1.1648077e+06, 1.2543946e+06, 1.3439815e+06,
#         1.4335684e+06, 1.5231553e+06, 1.6127422e+06, 1.7023291e+06,
#         1.7919160e+06]),
#  <BarContainer object of 20 artists>)

# %%
data=pd.DataFrame(df['Votes'].value_counts(bins=50)).reset_index()

# %%
data.drop([0],inplace=True)

# %%
data
# Out:
#                        index  Votes
# 1       (36012.76, 71847.52]    111
# 2      (71847.52, 107682.28]    110
# 3     (107682.28, 143517.04]     82
# 4      (143517.04, 179351.8]     66
# 5      (179351.8, 215186.56]     60
# 6     (215186.56, 251021.32]     46
# 7      (322690.84, 358525.6]     37
# 8     (251021.32, 286856.08]     36
# 9     (286856.08, 322690.84]     35
# 10     (358525.6, 394360.36]     18
# 11    (466029.88, 501864.64]     17
# 12    (394360.36, 430195.12]     17
# 13    (430195.12, 466029.88]     14
# 14     (501864.64, 537699.4]     13
# 15     (537699.4, 573534.16]     13
# 16    (609368.92, 645203.68]      6
# 17    (573534.16, 609368.92]      5
# 18    (645203.68, 681038.44]      4
# 19     (716873.2, 752707.96]      3
# 20    (931881.76, 967716.52]      3
# 21   (1039386.04, 1075220.8]      2
# 22   (1576907.44, 1612742.2]      1
# 23   (1218559.84, 1254394.6]      1
# 24  (1003551.28, 1039386.04]      1
# 25     (896047.0, 931881.76]      1
# ...

# %%
i=0
for x in data['Votes']:
    if(x==0):
         data.drop([i])
    i=i+1

# %%
df
# Out:
#      Rank                     Title                     Genre  \
# 0       1   Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2                Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                     Split           Horror,Thriller
# 3       4                      Sing   Animation,Comedy,Family
# 4       5             Suicide Squad  Action,Adventure,Fantasy
# ..    ...                       ...                       ...
# 993   994  Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                 Project X                    Comedy
# 996   997           Hostel: Part II                    Horror
# 997   998    Step Up 2: The Streets       Drama,Music,Romance
# 999  1000                Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
data
# Out:
#                        index  Votes
# 1       (36012.76, 71847.52]    111
# 2      (71847.52, 107682.28]    110
# 3     (107682.28, 143517.04]     82
# 4      (143517.04, 179351.8]     66
# 5      (179351.8, 215186.56]     60
# 6     (215186.56, 251021.32]     46
# 7      (322690.84, 358525.6]     37
# 8     (251021.32, 286856.08]     36
# 9     (286856.08, 322690.84]     35
# 10     (358525.6, 394360.36]     18
# 11    (466029.88, 501864.64]     17
# 12    (394360.36, 430195.12]     17
# 13    (430195.12, 466029.88]     14
# 14     (501864.64, 537699.4]     13
# 15     (537699.4, 573534.16]     13
# 16    (609368.92, 645203.68]      6
# 17    (573534.16, 609368.92]      5
# 18    (645203.68, 681038.44]      4
# 19     (716873.2, 752707.96]      3
# 20    (931881.76, 967716.52]      3
# 21   (1039386.04, 1075220.8]      2
# 22   (1576907.44, 1612742.2]      1
# 23   (1218559.84, 1254394.6]      1
# 24  (1003551.28, 1039386.04]      1
# 25     (896047.0, 931881.76]      1
# ...

# %%
p=[20,40,60,80,100]

# %%
plt.figure(figsize=(10,3),facecolor='lightblue',edgecolor='k',linewidth=2)
plt.pie(p,autopct='%0.2f%%',shadow=True,explode=[0,0,0,0.2,0])
plt.show()

# %%
temp= [14.2,16.4,11.9,15.2,18.5,22.1,19.4]
icecream_sales=[215,325,185,332,406,522,412]
tea_sales=[80,65,89,70,56,45,43]

# %% [markdown]
# scatterplot

# %%
plt.scatter(temp,icecream_sales)
plt.title('TEMP VS ICE CREAM')
plt.xlabel('TEMPERATURE')
plt.ylabel('ICE CREAM SALES')
plt.show()

# %%
plt.scatter(temp,icecream_sales,s=102,c='r',marker='o',edgecolor='black',linewidth=2,
           alpha=0.4)
plt.title('TEMP VS ICE CREAM')
plt.xlabel('TEMPERATURE')
plt.ylabel('ICE CREAM SALES')
plt.show()

# %%
color=[x for x in range(11,10)]
color
# Out:
# []

# %%
plt.scatter(temp,icecream_sales,s=102,c='r',marker='o',edgecolor='black',linewidth=2,
           alpha=1,cmap='Oranges')
plt.title('TEMP VS ICE CREAM')
plt.xlabel('TEMPERATURE')
plt.ylabel('ICE CREAM SALES')

plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12048\4184492686.py:1: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(temp,icecream_sales,s=102,c='r',marker='o',edgecolor='black',linewidth=2,

# %%
plt.scatter(temp,icecream_sales,s=[102,104,5,500,400,20,40],c='r',marker='o',edgecolor='black',linewidth=2,
           alpha=1,cmap='Oranges',vmin=10,vmax=20)
plt.title('TEMP VS ICE CREAM')
plt.xlabel('TEMPERATURE')
plt.ylabel('ICE CREAM SALES')
plt.colorbar().set_label('HIIII')
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12048\3396512490.py:1: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'vmin', 'vmax' will be ignored
#   plt.scatter(temp,icecream_sales,s=[102,104,5,500,400,20,40],c='r',marker='o',edgecolor='black',linewidth=2,

# %%
#subplots

# %%
df=pd.read_csv(r"C:\Users\ASUS\Downloads\Iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
plt.suptitle('Iris Dataset')
plt.subplot(1,2,1)
plt.title('LENGTH')
plt.subplot(1,2,2)
plt.title('WIDTH')

plt.tight_layout()
plt.show()

# %%
plt.subplot(2,1,1)
plt.subplot(2,1,2)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20,8),facecolor='lightblue',edgecolor='red',linewidth=2)
plt.suptitle('FOUR HISTOGRAMS')
plt.subplot(2,2,1)
plt.title('FIRST')
plt.subplot(2,2,2)
plt.title('SECOND')
plt.subplot(2,2,3)
plt.title('THIRD')
plt.subplot(2,2,4)
plt.title('FOUR')
plt.tight_layout()
plt.show()

# %%
fig,(ax1,ax2)=plt.subplots(nrows=1,ncols=2)
